# %%
import os
print(os.getcwd())
# Out:
# D:\Document-Type-Classifier

# %%
import ctypes
import os

torch_lib = r"C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\Lib\site-packages\torch\lib"

ctypes.CDLL(os.path.join(torch_lib, "torch_python.dll"))
print("torch_python loaded")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 6
#       2 import os
#       4 torch_lib = r"C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\Lib\site-packages\torch\lib"
# ----> 6 ctypes.CDLL(os.path.join(torch_lib, "torch_python.dll"))
#       7 print("torch_python loaded")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ctypes\__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371 self._FuncPtr = _FuncPtr
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#     376     self._handle = handle
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed

# %%
import os

folders = [
    "data/raw",
    "data/processed",
    "data/metadata",
    "notebooks",
    "src",
    "checkpoints",
    "results",
    "models",
    "reports"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Project structure created successfully!")
# Out:
# Project structure created successfully!

# %%
D:\Document-Type-Classifier\data\raw\Training_half
# Out:
#   Cell In[4], line 1
#     D:\Document-Type-Classifier\data\raw\Training_half
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
import os
print(os.getcwd())
# Out:
# D:\Document-Type-Classifier

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'checkpoints', 'data', 'models', 'notebook', 'notebooks', 'reports', 'results', 'src', 'Untitled.ipynb']

# %%
from pathlib import Path

dataset_path = Path("data/raw/Training_half")

print(dataset_path.exists())
# Out:
# True

# %%
from pathlib import Path
import os
import random
from collections import Counter

import matplotlib.pyplot as plt
from PIL import Image

# %%
files = list(dataset_path.glob("*.tif"))

print("Total Images:", len(files))
print("\nFirst 10 Files:")

for file in files[:10]:
    print(file.name)
# Out:
# Total Images: 159999
#
# First 10 Files:
# advertisement0.tif
# advertisement1.tif
# advertisement10.tif
# advertisement100.tif
# advertisement1000.tif
# advertisement10000.tif
# advertisement10001.tif
# advertisement10002.tif
# advertisement10003.tif
# advertisement10004.tif

# %%
from PIL import Image

img = Image.open(files[0])

print("Image Size :", img.size)
print("Image Mode :", img.mode)
print("Image Format :", img.format)
# Out:
# Image Size : (762, 1000)
# Image Mode : L
# Image Format : TIFF

# %%
import matplotlib.pyplot as plt
import random

sample = random.sample(files, 6)

plt.figure(figsize=(12,8))

for i, file in enumerate(sample):
    img = Image.open(file)

    plt.subplot(2,3,i+1)
    plt.imshow(img, cmap="gray")
    plt.title(file.stem)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\python.exe

# %%
import sys
print(sys.version)
# Out:
# 3.10.2 (tags/v3.10.2:a58ebcc, Jan 17 2022, 14:12:15) [MSC v.1929 64 bit (AMD64)]

# %%
import ipykernel
print(ipykernel.__file__)
# Out:
# C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\__init__.py

# %%
import jupyter_client
print(jupyter_client.__version__)
# Out:
# 7.4.1

# %%
import pytorch as pp
print(pp.version)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pytorch as pp
#       2 print(pp.version)
#
# ModuleNotFoundError: No module named 'pytorch'

# %%
import torch

print(torch.__version__)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import torch
#       3 print(torch.__version__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:287
#     283                     raise err
#     285         kernel32.SetErrorMode(prev_error_mode)
# --> 287     _load_dll_libraries()
#     288     del _load_dll_libraries
#     291 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     292     # Libraries can either be in
#     293     # path/nvidia/lib_folder/lib or
#     294     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     295     # path/lib_folder/lib
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:270, in _load_dll_libraries()
#     266     err = ctypes.WinError(last_error)
#     267     err.strerror += (
# ...

# %%
import os
print(os.environ["PATH"])
# Out:
# C:\Users\saurabh singh\bin;C:\Program Files\Git\mingw64\bin;C:\Program Files\Git\usr\local\bin;C:\Program Files\Git\usr\bin;C:\Program Files\Git\usr\bin;C:\Program Files\Git\mingw64\bin;C:\Program Files\Git\usr\bin;C:\Users\saurabh singh\bin;C:\Program Files\Common Files\Oracle\Java\javapath;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0;C:\WINDOWS\System32\OpenSSH;C:\Program Files\dotnet;D:\matlab\runtime\win64;D:\matlab\bin;D:\putty;C:\Program Files\Git\cmd;C:\Program Files\Graphviz\bin;C:\Program Files\MySQL\MySQL Shell 8.0\bin;C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\Scripts;C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310;C:\Users\saurabh singh\AppData\Local\Microsoft\WindowsApps;E:\java ide\IntelliJ IDEA Community Edition 2020.2.3\bin;C:\Users\saurabh singh\AppData\Local\Programs\Microsoft VS Code\bin;C:\Program Files (x86)\mingw-w64\i686-8.1.0-posix-dwarf-rt_v6-rev0\mingw32\bin;C:\Program F
# ...

# %%
import sys
print(sys.executable)
print(sys.prefix)
# Out:
# C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\python.exe
# C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310

# %%
import subprocess

subprocess.run(
    ["python", "-c", "import torch; print(torch.__version__)"],
    capture_output=True,
    text=True
)
result = subprocess.run(
    ["python", "-c", "import torch; print(torch.__version__)"],
    capture_output=True,
    text=True
)

print("STDOUT:")
print(result.stdout)

print("STDERR:")
print(result.stderr)

print("Return code:", result.returncode)
# Out:
# STDOUT:
# 2.12.1+cpu
#
# STDERR:
#
# Return code: 0

# %%
import subprocess

subprocess.run(
    ["python", "-m", "ipykernel", "--version"],
    text=True
)
# Out:
# CompletedProcess(args=['python', '-m', 'ipykernel', '--version'], returncode=120)

# %%
import ctypes
import os

torch_lib = r"C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\Lib\site-packages\torch\lib"

os.add_dll_directory(torch_lib)

for dll in [
    "c10.dll",
    "fbgemm.dll",
    "torch_cpu.dll"
]:
    try:
        ctypes.CDLL(os.path.join(torch_lib, dll))
        print(f"{dll}: OK")
    except Exception as e:
        print(f"{dll}: FAILED")
        print(e)
# Out:
# c10.dll: FAILED
# [WinError 1114] A dynamic link library (DLL) initialization routine failed
# fbgemm.dll: FAILED
# Could not find module 'C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\Lib\site-packages\torch\lib\fbgemm.dll' (or one of its dependencies). Try using the full path with constructor syntax.
# torch_cpu.dll: FAILED
# [WinError 1114] A dynamic link library (DLL) initialization routine failed

# %%
import ctypes
import os

torch_lib = r"C:\Users\saurabh singh\AppData\Local\Programs\Python\Python310\Lib\site-packages\torch\lib"

ctypes.CDLL(os.path.join(torch_lib, "libiomp5md.dll"))

print("Loaded Intel OpenMP")
# Out:
# Loaded Intel OpenMP
