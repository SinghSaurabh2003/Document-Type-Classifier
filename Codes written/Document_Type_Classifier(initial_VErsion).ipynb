# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/SinghSaurabh2003/Document-Type-Classifier.git
# Out:
# Cloning into 'Document-Type-Classifier'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 88 (delta 38), reused 11 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (88/88), 930.34 KiB | 20.22 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %cd Document-Type-Classifier
# Out:
# /content/Document-Type-Classifier

# %%
#To remove extra clone directory( folder inside folder)DO not run

# %cd /content
# !rm -rf Document-Type-Classifier
# Out:
# /content

# %%
#To check clone toh nhi ban gye document-type-classifier ke andar document-type classifier.
# !find /content -maxdepth 3 -type d -name "Document-Type-Classifier"

# %%
# !ls
# Out:
# src  train.py  Untitled1.ipynb	Untitled.ipynb

# %%
# !pip install torch torchvision tqdm pillow

# %%
# !pwd
# !ls -la
# Out:
# /content/Document-Type-Classifier
# total 780
# drwxr-xr-x 4 root root   4096 Jun 21 13:26 .
# drwxr-xr-x 1 root root   4096 Jun 21 13:26 ..
# drwxr-xr-x 8 root root   4096 Jun 21 13:26 .git
# -rw-r--r-- 1 root root   1212 Jun 21 13:26 .gitignore
# drwxr-xr-x 2 root root   4096 Jun 21 13:26 src
# -rw-r--r-- 1 root root   6298 Jun 21 13:26 train.py
# -rw-r--r-- 1 root root 560684 Jun 21 13:26 Untitled1.ipynb
# -rw-r--r-- 1 root root 207714 Jun 21 13:26 Untitled.ipynb

# %%
import torch

print("Torch:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch: 2.11.0+cu128
# CUDA Available: True
# GPU: Tesla T4

# %%
# !mkdir -p /content/data

# !unzip -q "/content/drive/MyDrive/RVLCDIP/archive (3).zip" -d /content/data

# %%
import os

dataset_path = "/content/data/Training_half"

print("Exists:", os.path.exists(dataset_path))
print("Files:", len(os.listdir(dataset_path)))
# Out:
# Exists: True
# Files: 159999

# %%
import os

print(os.path.exists("/content/data/Training_half"))
print(len(os.listdir("/content/data/Training_half")))

print(os.listdir("/content/data/Training_half")[:10])
# Out:
# True
# 159999
# ['advertisement19319.tif', 'form18958.tif', 'form15114.tif', 'letter1120.tif', 'budget15555.tif', 'invoice6757.tif', 'budget5892.tif', 'advertisement4099.tif', 'budget2203.tif', 'invoice14288.tif']

# %%
import torch

checkpoint_path = "/content/drive/MyDrive/Document-Type-Classifier/checkpoints/last_model.pth"

checkpoint = torch.load(checkpoint_path, map_location="cpu")

print("Current saved epoch:", checkpoint["epoch"])

# Set it so training resumes from Epoch 2
checkpoint["epoch"] = 3

torch.save(checkpoint, checkpoint_path)

print("Checkpoint updated.")
# Out:
# Current saved epoch: 3
# Checkpoint updated.

# %%
# !python train.py
# Out:
# ...
# Using Device : cuda
# ...
# Total Images : 159999
# Classes : ['advertisement', 'budget', 'email', 'filefolder', 'form', 'handwritten', 'invoice', 'letter', 'memo']
# Training Batches : 4000
# Validation Batches : 1000
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 216MB/s]
# ...
# Resuming from LAST checkpoint
# ...
# Starting from Epoch 4
# Best Accuracy : 76.39%
#
# ...
# Epoch 4/10
# ...
# 100% 4000/4000 [21:20<00:00,  3.12it/s, accuracy=75.4, loss=0.526]
#
# Train Loss : 0.7461
# Train Accuracy : 75.43%
# Validation Loss : 0.7130
# Validation Accuracy : 76.60%
# Learning Rate : 0.000100
#
# ✅ Best Model Saved!
#
# ...
# Epoch 5/10
# ...
# 100% 4000/4000 [21:08<00:00,  3.15it/s, accuracy=75.9, loss=0.59]
#
# Train Loss : 0.7355
# Train Accuracy : 75.86%
# Validation Loss : 0.7047
# Validation Accuracy : 76.93%
# Learning Rate : 0.000100
#
# ✅ Best Model Saved!
#
# ...
# Epoch 6/10
# ...

# %%
import os

print(os.path.exists("/content/drive/MyDrive/Document-Type-Classifier/checkpoints/best_model.pth"))
# Out:
# False

# %%
import src.dataset
print(src.dataset.__file__)
# Out:
# /content/Document-Type-Classifier/Document-Type-Classifier/src/dataset.py

# %%
# !find /content -maxdepth 3 -type d -name "Document-Type-Classifier"
# Out:
# /content/drive/MyDrive/Document-Type-Classifier
# /content/Document-Type-Classifier
# /content/Document-Type-Classifier/Document-Type-Classifier

# %%
import torch

checkpoint = torch.load("/content/drive/MyDrive/Document-Type-Classifier/checkpoints/best_model.pth")

print(checkpoint["epoch"])
print(checkpoint["best_accuracy"])
# Out:
# 2
# 74.72108503390731

# %%
# !unzip -q "/content/drive/MyDrive/Testing/test.zip" -d /content/data

# %%
# !python predict2.py
# Out:
# python3: can't open file '/content/predict2.py': [Errno 2] No such file or directory

# %%
# !cwd
# Out:
# /bin/bash: line 1: cwd: command not found

# %%
# %cd /content/Document-Type-Classifier/
# Out:
# /content/Document-Type-Classifier

# %%
# !python predict2.py
# Out:
# ...
# Using Device : cuda
# ...
#
# Loading Model...
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 135MB/s]
# Model Loaded Successfully!
#
#
# ...
# Prediction
# ...
# Image Path      : /content/data/test/invoice/0000023361.tif
# Prediction      : invoice
# Confidence      : 84.12%
#
#
# ...
# Top 3 Predictions
# ...
# 1. invoice              84.12%
# 2. advertisement        4.67%
# 3. letter               3.47%
#
#
# ...
# Prediction Completed
# ...
