# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: protobuf<8,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.52.1)
# Requirement already satisfied: uvicorn>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (15.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.0.0->streamlit) (3.18)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2026.5.20)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.58.0-py3-none-any.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 56.5 MB/s eta 0:00:00
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 49.9 MB/s eta 0:00:00
# Installing collected packages: pydeck, streamlit
# Successfully installed pydeck-0.9.2 streamlit-1.58.0

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# added 22 packages in 3s
# ⠹
# ⠹3 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %%
# !git clone https://github.com/SinghSaurabh2003/Document-Type-Classifier.git
# Out:
# Cloning into 'Document-Type-Classifier'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 116 (delta 50), reused 11 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (116/116), 1.26 MiB | 4.95 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# %cd /content/Document-Type-Classifier/
# Out:
# /content/Document-Type-Classifier

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !lt --port 8501
# Out:
# your url is: https://soft-bananas-show.loca.lt
# ^C

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared

# %%
# !pkill -f streamlit
# !pkill -f cloudflared

# %%
# %cd /content/Document-Type-Classifier
# Out:
# /content/Document-Type-Classifier

# %%
# !streamlit run app.py > streamlit.log 2>&1 &

# %%
# !cat streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-06-26 11:04:10.374 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.151.217:8501

# %%
# !./cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-06-26T11:04:17Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-06-26T11:04:17Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-06-26T11:04:21Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-26T11:04:21Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-06-26T11:04:21Z INF |  https://dicke-democrats-utilities-concerns.trycloudflare.com                              |
# 2026-06-26T11:04:21Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-26T11:04:21Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-06-26T11:04:21Z INF Version 2026.6.1 (Checksum 5861a10a438fe8ddcfebb3b830f83966cbf193edafce0fe2eeb198fbae1f7a22)
# 2026-06-26T11:04:21Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-06-26T11:04:21Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-06-26T11:04:21Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-06-26T11:04:21Z INF Generated Connector ID: ba81f80d-ad30-4de2-9630-03ae9643cf9a
# 2026-06-26T11:04:21Z INF Initial protocol quic
# 2026-06-26T11:04:21Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-26T11:04:21Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/06/26 11:04:21 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-06-26T11:04:21Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-26T11:04:21Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-06-26T11:04:21Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-06-26T11:04:21Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.77
# 2026-06-26T11:04:21Z INF Registered tunnel connection connIndex=0 connection=51b0bd9c-fc43-47de-95b7-a882b071d5bc event=0 ip=198.41.192.77 location=lax07 protocol=quic
# 2026-06-26T11:04:27Z INF +-------------------------------------------------------------------------------------+
# 2026-06-26T11:04:27Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-06-26T11:04:27Z INF +-------------------------------------------------------------------------------------+
# 2026-06-26T11:04:27Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-06-26T11:04:27Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-26T11:04:27Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-26T11:04:27Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-26T11:04:27Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-26T11:04:27Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-26T11:04:27Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-26T11:04:27Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-06-26T11:04:27Z INF |                                                                                     |
# 2026-06-26T11:04:27Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-06-26T11:04:27Z INF +-------------------------------------------------------------------------------------+
# 2026-06-26T11:04:27Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=238bda1c-3f4f-439f-ba88-60248932f1fa status=pass target=region1.v2.argotunnel.com
# 2026-06-26T11:04:27Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=238bda1c-3f4f-439f-ba88-60248932f1fa status=pass target=region2.v2.argotunnel.com
# 2026-06-26T11:04:27Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=238bda1c-3f4f-439f-ba88-60248932f1fa status=pass target=region1.v2.argotunnel.com
# 2026-06-26T11:04:27Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=238bda1c-3f4f-439f-ba88-60248932f1fa status=pass target=region2.v2.argotunnel.com
# 2026-06-26T11:04:27Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=238bda1c-3f4f-439f-ba88-60248932f1fa status=pass target=region1.v2.argotunnel.com
# 2026-06-26T11:04:27Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=238bda1c-3f4f-439f-ba88-60248932f1fa status=pass target=region2.v2.argotunnel.com
# 2026-06-26T11:04:27Z INF precheck component="Cloudflare API" details="API is reachable" run_id=238bda1c-3f4f-439f-ba88-60248932f1fa status=pass target=api.cloudflare.com:443
# 2026-06-26T11:04:27Z INF precheck complete hard_fail=false run_id=238bda1c-3f4f-439f-ba88-60248932f1fa suggested_protocol=quic
# 2026-06-26T11:05:24Z INF Initiating graceful shutdown due to signal interrupt ...
# 2026-06-26T11:05:24Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.77
# 2026-06-26T11:05:24Z ERR failed to serve tunnel connection error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.77
# 2026-06-26T11:05:24Z ERR Serve tunnel error error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.77
# 2026-06-26T11:05:24Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.192.77
# 2026-06-26T11:05:24Z ERR Connection terminated connIndex=0
# 2026-06-26T11:05:24Z ERR no more connections active and exiting
# 2026-06-26T11:05:24Z INF Tunnel server stopped
# 2026-06-26T11:05:24Z INF Metrics server stopped

# %%
# !tail -100 streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-06-23 21:37:06.269 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.199.8.24:8501
#
#   Stopping...

# %%
# !pkill -f streamlit
# !pkill -f cloudflared

# %%
# !streamlit run app.py > streamlit.log 2>&1 &

# %%
# !ps -ef | grep streamlit
# Out:
# root       11749       1 22 21:43 ?        00:00:02 /usr/bin/python3 /usr/local/bin/streamlit run app.py
# root       11811    3729  0 21:43 ?        00:00:00 /bin/bash -c ps -ef | grep streamlit
# root       11813   11811  0 21:43 ?        00:00:00 grep streamlit

# %%
# !tail -100 streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-06-23 21:43:29.744 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.199.8.24:8501
#
# 2026-06-23 21:45:25.062 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-23 21:45:31.351 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
#   Stopping...

# %%
# !./cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-06-23T21:47:30Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-06-23T21:47:30Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-06-23T21:47:34Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-23T21:47:34Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-06-23T21:47:34Z INF |  https://diego-cathedral-richardson-enjoyed.trycloudflare.com                              |
# 2026-06-23T21:47:34Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-23T21:47:34Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-06-23T21:47:34Z INF Version 2026.6.1 (Checksum 5861a10a438fe8ddcfebb3b830f83966cbf193edafce0fe2eeb198fbae1f7a22)
# 2026-06-23T21:47:34Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-06-23T21:47:34Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-06-23T21:47:34Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-06-23T21:47:34Z INF Generated Connector ID: bc1c8036-a236-468c-801c-2d6bb2af8dd3
# 2026-06-23T21:47:34Z INF Initial protocol quic
# 2026-06-23T21:47:34Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-23T21:47:34Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/06/23 21:47:34 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-06-23T21:47:34Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-23T21:47:34Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-06-23T21:47:34Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-06-23T21:47:34Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.200.233
# 2026-06-23T21:47:34Z INF Registered tunnel connection connIndex=0 connection=bac3311e-41e9-48f8-a708-2ce987b5c581 event=0 ip=198.41.200.233 location=iad19 protocol=quic
# 2026-06-23T21:47:40Z INF +-------------------------------------------------------------------------------------+
# 2026-06-23T21:47:40Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-06-23T21:47:40Z INF +-------------------------------------------------------------------------------------+
# 2026-06-23T21:47:40Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-06-23T21:47:40Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-23T21:47:40Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-23T21:47:40Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-23T21:47:40Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-23T21:47:40Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-23T21:47:40Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-23T21:47:40Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-06-23T21:47:40Z INF |                                                                                     |
# 2026-06-23T21:47:40Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-06-23T21:47:40Z INF +-------------------------------------------------------------------------------------+
# 2026-06-23T21:47:40Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a status=pass target=region1.v2.argotunnel.com
# 2026-06-23T21:47:40Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a status=pass target=region2.v2.argotunnel.com
# 2026-06-23T21:47:40Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a status=pass target=region1.v2.argotunnel.com
# 2026-06-23T21:47:40Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a status=pass target=region2.v2.argotunnel.com
# 2026-06-23T21:47:40Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a status=pass target=region1.v2.argotunnel.com
# 2026-06-23T21:47:40Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a status=pass target=region2.v2.argotunnel.com
# 2026-06-23T21:47:40Z INF precheck component="Cloudflare API" details="API is reachable" run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a status=pass target=api.cloudflare.com:443
# 2026-06-23T21:47:40Z INF precheck complete hard_fail=false run_id=7d70fe0d-b4ef-4b42-9be1-64a01e4ed78a suggested_protocol=quic
# 2026-06-23T21:47:48Z ERR  error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp [::1]:8501: connect: connection refused" connIndex=0 event=1 ingressRule=0 originService=http://localhost:8501
# 2026-06-23T21:47:48Z ERR Request failed error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp [::1]:8501: connect: connection refused" connIndex=0 dest=https://diego-cathedral-richardson-enjoyed.trycloudflare.com/ event=0 ip=198.41.200.233 type=http
# 2026-06-23T21:47:49Z ERR  error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp [::1]:8501: connect: connection refused" connIndex=0 event=1 ingressRule=0 originService=http://localhost:8501
# 2026-06-23T21:47:49Z ERR Request failed error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp [::1]:8501: connect: connection refused" connIndex=0 dest=https://diego-cathedral-richardson-enjoyed.trycloudflare.com/favicon.ico event=0 ip=198.41.200.233 type=http
# 2026-06-23T21:48:58Z INF Initiating graceful shutdown due to signal interrupt ...
# 2026-06-23T21:48:58Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.200.233
# 2026-06-23T21:48:58Z ERR failed to serve tunnel connection error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.200.233
# 2026-06-23T21:48:58Z ERR Serve tunnel error error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.200.233
# 2026-06-23T21:48:58Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.200.233
# 2026-06-23T21:48:58Z ERR Connection terminated connIndex=0
# 2026-06-23T21:48:58Z ERR no more connections active and exiting
# 2026-06-23T21:48:58Z INF Tunnel server stopped
# 2026-06-23T21:48:58Z INF Metrics server stopped

# %%
# !pkill -f streamlit
# !pkill -f cloudflared

# %%
# !streamlit run app.py > streamlit.log 2>&1 &

# %%
# !tail -100 streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-06-24 12:04:50.698 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://104.198.73.114:8501

# %%
# !./cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-06-24T12:04:57Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-06-24T12:04:57Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-06-24T12:05:01Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-24T12:05:01Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-06-24T12:05:01Z INF |  https://chosen-natural-preference-rid.trycloudflare.com                                   |
# 2026-06-24T12:05:01Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-24T12:05:01Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-06-24T12:05:01Z INF Version 2026.6.1 (Checksum 5861a10a438fe8ddcfebb3b830f83966cbf193edafce0fe2eeb198fbae1f7a22)
# 2026-06-24T12:05:01Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-06-24T12:05:01Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-06-24T12:05:01Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-06-24T12:05:01Z INF Generated Connector ID: 00e08d9d-42e3-46a5-8932-ae0125e15ab8
# 2026-06-24T12:05:01Z INF Initial protocol quic
# 2026-06-24T12:05:01Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-24T12:05:01Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/06/24 12:05:01 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-06-24T12:05:01Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-24T12:05:01Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-06-24T12:05:01Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-06-24T12:05:01Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.200.33
# 2026-06-24T12:05:01Z INF Registered tunnel connection connIndex=0 connection=37717cba-f0f0-40ca-b7a2-537164485686 event=0 ip=198.41.200.33 location=ord11 protocol=quic
# 2026-06-24T12:05:07Z INF +-------------------------------------------------------------------------------------+
# 2026-06-24T12:05:07Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-06-24T12:05:07Z INF +-------------------------------------------------------------------------------------+
# 2026-06-24T12:05:07Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-06-24T12:05:07Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-24T12:05:07Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-24T12:05:07Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-24T12:05:07Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-24T12:05:07Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-24T12:05:07Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-24T12:05:07Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-06-24T12:05:07Z INF |                                                                                     |
# 2026-06-24T12:05:07Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-06-24T12:05:07Z INF +-------------------------------------------------------------------------------------+
# 2026-06-24T12:05:07Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 status=pass target=region1.v2.argotunnel.com
# 2026-06-24T12:05:07Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 status=pass target=region2.v2.argotunnel.com
# 2026-06-24T12:05:07Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 status=pass target=region1.v2.argotunnel.com
# 2026-06-24T12:05:07Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 status=pass target=region2.v2.argotunnel.com
# 2026-06-24T12:05:07Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 status=pass target=region1.v2.argotunnel.com
# 2026-06-24T12:05:07Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 status=pass target=region2.v2.argotunnel.com
# 2026-06-24T12:05:07Z INF precheck component="Cloudflare API" details="API is reachable" run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 status=pass target=api.cloudflare.com:443
# 2026-06-24T12:05:07Z INF precheck complete hard_fail=false run_id=2d63a3c4-65c8-4285-84c2-11e6c18b2e12 suggested_protocol=quic
# 2026-06-24T12:06:08Z INF Initiating graceful shutdown due to signal interrupt ...
# ^C

# %%
# !pkill -f streamlit
# !pkill -f cloudflared

# %%
# !streamlit run app.py > streamlit.log 2>&1 &

# %%
# !tail -100 streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-06-24 12:10:25.571 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://104.198.73.114:8501

# %%
# !./cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-06-24T12:10:47Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-06-24T12:10:47Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-06-24T12:10:51Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-24T12:10:51Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-06-24T12:10:51Z INF |  https://styles-sandwich-number-represent.trycloudflare.com                                |
# 2026-06-24T12:10:51Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-24T12:10:51Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-06-24T12:10:51Z INF Version 2026.6.1 (Checksum 5861a10a438fe8ddcfebb3b830f83966cbf193edafce0fe2eeb198fbae1f7a22)
# 2026-06-24T12:10:51Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-06-24T12:10:51Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-06-24T12:10:51Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-06-24T12:10:51Z INF Generated Connector ID: 8d0f30e0-7be2-46cd-8c21-7d26639e3799
# 2026-06-24T12:10:51Z INF Initial protocol quic
# 2026-06-24T12:10:51Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-24T12:10:51Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/06/24 12:10:51 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-06-24T12:10:51Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-24T12:10:51Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-06-24T12:10:51Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-06-24T12:10:51Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.37
# 2026-06-24T12:10:51Z INF Registered tunnel connection connIndex=0 connection=7efc1820-502d-4cef-a410-1be02fef4315 event=0 ip=198.41.192.37 location=ord06 protocol=quic
# 2026-06-24T12:10:57Z INF +-------------------------------------------------------------------------------------+
# 2026-06-24T12:10:57Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-06-24T12:10:57Z INF +-------------------------------------------------------------------------------------+
# 2026-06-24T12:10:57Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-06-24T12:10:57Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-24T12:10:57Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-24T12:10:57Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-24T12:10:57Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-24T12:10:57Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-24T12:10:57Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-24T12:10:57Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-06-24T12:10:57Z INF |                                                                                     |
# 2026-06-24T12:10:57Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-06-24T12:10:57Z INF +-------------------------------------------------------------------------------------+
# 2026-06-24T12:10:57Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=41394e75-6440-436f-8e99-d19f497f1c74 status=pass target=region1.v2.argotunnel.com
# 2026-06-24T12:10:57Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=41394e75-6440-436f-8e99-d19f497f1c74 status=pass target=region2.v2.argotunnel.com
# 2026-06-24T12:10:57Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=41394e75-6440-436f-8e99-d19f497f1c74 status=pass target=region1.v2.argotunnel.com
# 2026-06-24T12:10:57Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=41394e75-6440-436f-8e99-d19f497f1c74 status=pass target=region2.v2.argotunnel.com
# 2026-06-24T12:10:57Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=41394e75-6440-436f-8e99-d19f497f1c74 status=pass target=region1.v2.argotunnel.com
# 2026-06-24T12:10:57Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=41394e75-6440-436f-8e99-d19f497f1c74 status=pass target=region2.v2.argotunnel.com
# 2026-06-24T12:10:57Z INF precheck component="Cloudflare API" details="API is reachable" run_id=41394e75-6440-436f-8e99-d19f497f1c74 status=pass target=api.cloudflare.com:443
# 2026-06-24T12:10:57Z INF precheck complete hard_fail=false run_id=41394e75-6440-436f-8e99-d19f497f1c74 suggested_protocol=quic
# 2026-06-24T12:12:02Z INF Initiating graceful shutdown due to signal interrupt ...
# 2026-06-24T12:12:02Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.37
# 2026-06-24T12:12:02Z ERR failed to serve tunnel connection error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.37
# 2026-06-24T12:12:02Z ERR Serve tunnel error error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.37
# 2026-06-24T12:12:02Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.192.37
# 2026-06-24T12:12:02Z ERR Connection terminated connIndex=0
# 2026-06-24T12:12:02Z ERR no more connections active and exiting
# 2026-06-24T12:12:02Z INF Tunnel server stopped
# 2026-06-24T12:12:02Z INF Metrics server stopped

# %%
# !pkill -f streamlit
# !pkill -f cloudflared

# %%
# !streamlit run app.py > streamlit.log 2>&1 &

# %%
# !tail -100 streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-06-26 11:07:00.562 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.151.217:8501

# %%
# !./cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-06-26T11:07:03Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-06-26T11:07:03Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-06-26T11:07:07Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-26T11:07:07Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-06-26T11:07:07Z INF |  https://publicity-ranges-guam-dana.trycloudflare.com                                      |
# 2026-06-26T11:07:07Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-26T11:07:07Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-06-26T11:07:07Z INF Version 2026.6.1 (Checksum 5861a10a438fe8ddcfebb3b830f83966cbf193edafce0fe2eeb198fbae1f7a22)
# 2026-06-26T11:07:07Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-06-26T11:07:07Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-06-26T11:07:07Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-06-26T11:07:07Z INF Generated Connector ID: 16d2d904-2319-49b4-800d-059ad9df5aa6
# 2026-06-26T11:07:07Z INF Initial protocol quic
# 2026-06-26T11:07:07Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-26T11:07:07Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/06/26 11:07:07 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-06-26T11:07:07Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-26T11:07:07Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-06-26T11:07:07Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-06-26T11:07:07Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.200.13
# 2026-06-26T11:07:07Z INF Registered tunnel connection connIndex=0 connection=337a51d3-30dc-4cdb-826a-baa3231ea26a event=0 ip=198.41.200.13 location=lax01 protocol=quic
# 2026-06-26T11:07:13Z INF +-------------------------------------------------------------------------------------+
# 2026-06-26T11:07:13Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-06-26T11:07:13Z INF +-------------------------------------------------------------------------------------+
# 2026-06-26T11:07:13Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-06-26T11:07:13Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-26T11:07:13Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-26T11:07:13Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-26T11:07:13Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-26T11:07:13Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-26T11:07:13Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-26T11:07:13Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-06-26T11:07:13Z INF |                                                                                     |
# 2026-06-26T11:07:13Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-06-26T11:07:13Z INF +-------------------------------------------------------------------------------------+
# 2026-06-26T11:07:13Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=339af322-1442-4502-9361-9511a2fa2939 status=pass target=region1.v2.argotunnel.com
# 2026-06-26T11:07:13Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=339af322-1442-4502-9361-9511a2fa2939 status=pass target=region2.v2.argotunnel.com
# 2026-06-26T11:07:13Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=339af322-1442-4502-9361-9511a2fa2939 status=pass target=region1.v2.argotunnel.com
# 2026-06-26T11:07:13Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=339af322-1442-4502-9361-9511a2fa2939 status=pass target=region2.v2.argotunnel.com
# 2026-06-26T11:07:13Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=339af322-1442-4502-9361-9511a2fa2939 status=pass target=region1.v2.argotunnel.com
# 2026-06-26T11:07:13Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=339af322-1442-4502-9361-9511a2fa2939 status=pass target=region2.v2.argotunnel.com
# 2026-06-26T11:07:13Z INF precheck component="Cloudflare API" details="API is reachable" run_id=339af322-1442-4502-9361-9511a2fa2939 status=pass target=api.cloudflare.com:443
# 2026-06-26T11:07:13Z INF precheck complete hard_fail=false run_id=339af322-1442-4502-9361-9511a2fa2939 suggested_protocol=quic
# 2026-06-26T11:15:24Z INF Initiating graceful shutdown due to signal interrupt ...
# 2026-06-26T11:15:24Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.200.13
# 2026-06-26T11:15:24Z ERR failed to serve tunnel connection error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.200.13
# 2026-06-26T11:15:24Z ERR Serve tunnel error error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.200.13
# 2026-06-26T11:15:24Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.200.13
# 2026-06-26T11:15:24Z ERR Connection terminated connIndex=0
# 2026-06-26T11:15:24Z ERR no more connections active and exiting
# 2026-06-26T11:15:24Z INF Tunnel server stopped
# 2026-06-26T11:15:24Z INF Metrics server stopped
